# %%
import pandas
import matplotlib
import seaborn
df=pandas.read_csv("fastfood.csv")
df
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby’s
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl’s Jr.
# 5                         Checkers/Rally’s
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church’s Chicken
# 9                                 Culver’s
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 18                                Hardee’s
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %%
#display frt 5 sets
df.head()
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0           Arby’s                                            4462
# 1   Baskin-Robbins                                             686
# 2        Bojangles                                            1485
# 3      Burger King                                           10033
# 4       Carl’s Jr.                                            1560
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                              1309               2293
# 1                                               296               2317
# 2                                              1924                496
# 3                                              1470               7054
# 4                                              1400               1011
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %%
#display last 5 sets
df.tail()
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 45          Wendy's                                           11111
# 46      Whataburger                                            3089
# 47     White Castle                                             615
# 48         Wingstop                                            2278
# 49          Zaxby’s                                            2233
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 45                                              1895               5535
# 46                                              3640                131
# 47                                              1749                  0
# 48                                              1592               1498
# 49                                              2484                761
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %%
df.shape
# Out:
# (50, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
df.describe()
# Out:
#        U.S. Systemwide Sales (Millions - U.S Dollars)  \
# count                                       50.000000
# mean                                      4965.060000
# std                                       7531.439444
# min                                        615.000000
# 25%                                        935.250000
# 50%                                       2289.500000
# 75%                                       5400.000000
# max                                      45960.000000
#
#        Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# count                                         50.000000           50.00000
# mean                                        1857.660000         2663.96000
# std                                         1163.266418         3801.49754
# min                                          296.000000            0.00000
# 25%                                         1084.000000          478.00000
# ...

# %%
#find wheater null values are there
df.isnull()
# Out:
#     Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0              False                                           False
# 1              False                                           False
# 2              False                                           False
# 3              False                                           False
# 4              False                                           False
# 5              False                                           False
# 6              False                                           False
# 7              False                                           False
# 8              False                                           False
# 9              False                                           False
# 10             False                                           False
# 11             False                                           False
# 12             False                                           False
# ...

# %%
#delete a row
df.drop(1,inplace=True)
df
# Out:
#                           Fast-Food Chains  \
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl’s Jr.
# 5                         Checkers/Rally’s
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church’s Chicken
# 9                                 Culver’s
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 18                                Hardee’s
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# 21                           Jersey Mike’s
# 22                            Jimmy John’s
# ...

# %%
#to delete the column
df.drop(columns="Company Stores",inplace=True)
df
# Out:
#                           Fast-Food Chains  \
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl’s Jr.
# 5                         Checkers/Rally’s
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church’s Chicken
# 9                                 Culver’s
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 18                                Hardee’s
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# 21                           Jersey Mike’s
# 22                            Jimmy John’s
# ...

# %%
#find the mean value 
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].mean()
# Out:
# 5064.6875

# %%
#finding median value
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].median()
# Out:
# 2289.5

# %%
#finding the maximum sale
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].max()
# Out:
# 45960

# %%
#finding the minimum sale
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].min()
# Out:
# 615

# %%
#to find the entriy row
df[df["U.S. Systemwide Sales (Millions - U.S Dollars)"]==df["U.S. Systemwide Sales (Millions - U.S Dollars)"].max()]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 28       McDonald’s                                           45960
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 28                                              3420              12775
#
#     2021 Total Units  Total Change in Units from 2020
# 28             13438                              244

# %%
#to find the minimum value 
df[df["U.S. Systemwide Sales (Millions - U.S Dollars)"]==df["U.S. Systemwide Sales (Millions - U.S Dollars)"].min()]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 47     White Castle                                             615
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 47                                              1749                  0
#
#     2021 Total Units  Total Change in Units from 2020
# 47               349                               -6

# %%
#to display bar plot
df.plot.bar(x="U.S. Systemwide Sales (Millions - U.S Dollars)",y="Average Sales per Unit (Thousands - U.S Dollars)")
# Out:
# <AxesSubplot: xlabel='U.S. Systemwide Sales (Millions - U.S Dollars)'>

# %%
#to find bar plot for first 10 data sets
df.head(10).plot.bar(x="U.S. Systemwide Sales (Millions - U.S Dollars)",y="Average Sales per Unit (Thousands - U.S Dollars)")
# Out:
# <AxesSubplot: xlabel='U.S. Systemwide Sales (Millions - U.S Dollars)'>

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.groupby(['Fast-Food Chains']).max().sort_values(by='U.S. Systemwide Sales (Millions - U.S Dollars)', ascending=False)['U.S. Systemwide Sales (Millions - U.S Dollars)']
# Out:
# Fast-Food Chains
# McDonald’s                                45960
# Starbucks                                 24300
# Chick-fil-A                               16700
# Taco Bell                                 12600
# Wendy's                                   11111
# Dunkin'                                   10416
# Burger King                               10033
# Subway                                     9350
# Domino's                                   8641
# Chipotle                                   7547
# Sonic Drive-In                             5835
# Panera Bread                               5650
# Pizza Hut                                  5500
# KFC                                        5100
# Popeyes Louisiana Kitchen                  4775
# Dairy Queen                                4494
# Panda Express                              4452
# Little Caesars                             4185
# Jack in the Box                            4077
# ...

# %%
#to find correlation
n=df.corr()
seaborn.heatmap(n,annot=True)
# Out:
# C:\Users\RAMYA\AppData\Local\Temp\ipykernel_8872\1673948309.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   n=df.corr()
# <AxesSubplot: >

# %%
df.head(10).plot.bar(x="2021 Total Units",y="Total Change in Units from 2020")
# Out:
# <AxesSubplot: xlabel='2021 Total Units'>
